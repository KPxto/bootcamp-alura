# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# O **Teorema do Limite Central** afirma que, com o aumento do tamanho da amostra, a distribuição das médias amostrais se aproxima de uma distribuição normal com média igual à média da população e desvio padrão igual ao desvio padrão da variável original dividido pela raiz quadrada do tamanho da amostra. Este fato é assegurado para $n$ maior ou igual a 30.
#
#
# .
# # $$\sigma_\bar{x} = \frac{\sigma}{\sqrt{n}}$$
# ​
# O desvio padrão das médias amostrais é conhecido como **erro padrão da média**

# %%
import pandas as pd
from zipfile import ZipFile



caminho = "PeNSE_2015_AMOSTRA2.zip"
zip = ZipFile(caminho)
caminho_pasta_zipada = zip.namelist()[1]

dados = pd.read_csv(zip.open(caminho_pasta_zipada), sep = ";", thousands = ".", decimal = ",")
dados.head()
# Out:
#    ANOPESQ  PAIS  REGEOGR  VB00004  VB01001  VB01002  VB01003  VB01004  \
# 0     2015    76        1        1        2        1       13        7
# 1     2015    76        1        1        2        1       14        4
# 2     2015    76        1        1        1        4       13        6
# 3     2015    76        1        1        1        1       14        6
# 4     2015    76        1        1        1        1       13        9
#
#    VB01005  VB01006  ...  ESTRATO_EXP  ESTRATOGEOREG        PESO  V0006  \
# 0        7        1  ...         1223              1  299.735235      1
# 1        7        1  ...         1223              1  355.170081      1
# 2        7        1  ...         1223              1  299.735235      1
# 3        7        1  ...         1223              1  355.170081      1
# 4        7        1  ...         1223              1  299.735235      1
#
#    V0007  V0008  V0041  aluno  escola  turma
# 0      2      4      1      1       1    296
# 1      2      4      1      2       1    296
# 2      2      4      1      3       1    296
# 3      2      4      1      4       1    296
# 4      2      4      1      5       1    296
#
# [5 rows x 181 columns]

# %%
dados["IMC"] = dados["VB17003"]/ ((dados["VB17004"]/100)**2)
dados["IMC"]
# Out:
# 0        15.051321
# 1        21.727839
# 2        18.502907
# 3        23.322831
# 4        28.122076
#            ...
# 16551    20.113223
# 16552    17.930782
# 16553    23.968489
# 16554    18.995343
# 16555    23.303246
# Name: IMC, Length: 16556, dtype: float64

# %%
n = 2000
total_de_amostras = 1500
amostras = pd.DataFrame()
for i in range(total_de_amostras):
  _ = dados.IMC.sample(n)
  _.index = range(0, len(_))
  amostras['Amostra_' + str(i)] = _

amostras
# Out:
#       Amostra_0  Amostra_1  Amostra_2  Amostra_3  Amostra_4  Amostra_5  \
# 0     18.903944  16.683673  21.308809  24.098988  16.203704  19.560443
# 1     36.611539  20.050398  17.399232  17.948891  17.097856  18.506650
# 2     21.156627  28.456105  18.770832  19.579922  14.656508  19.843012
# 3     25.093127  15.218399  17.913324  16.910748  19.965499  19.470899
# 4     18.347087  15.469156  20.416985  18.523300  16.964398  18.173385
# ...         ...        ...        ...        ...        ...        ...
# 1995  22.224226  20.904968  20.620650  24.250404  24.458933  17.889273
# 1996  16.468974  17.901556  17.037202  24.825710  18.426534  17.850394
# 1997  29.655612  33.516106  31.079681  20.745098  22.003864  22.760227
# 1998  16.544722  25.848659  21.216882  16.021657  18.715145  22.212594
# 1999  17.744646  21.216253  23.590229  17.695549  14.627275  20.396037
#
#       Amostra_6  Amostra_7  Amostra_8  Amostra_9  ...  Amostra_1490  \
# 0     17.821765  16.857440  16.578188  20.176814  ...     25.896934
# 1     19.375000  15.760750  21.639683  18.930604  ...     20.251488
# 2     18.078890  21.319919  19.255328  18.619324  ...     22.712983
# 3     30.194448  17.853186  20.834896  19.817917  ...     17.496545
# 4     19.722233  28.080249  16.786921  20.225449  ...     15.620821
# ...         ...        ...        ...        ...  ...           ...
# 1995  19.360130  22.097926  22.143631  26.677862  ...     21.500866
# 1996  20.959059  18.145087  25.449168  23.023480  ...     20.434520
# 1997  19.399241  21.617829  14.355414  18.984338  ...     13.072400
# 1998  16.435171  15.536010  17.566776  26.967574  ...     21.583915
# 1999  25.015170  16.885652  13.678633  16.354296  ...     24.148399
#
#       Amostra_1491  Amostra_1492  Amostra_1493  Amostra_1494  Amostra_1495  \
# 0        30.375296     26.700968     20.811655     17.551494     21.453574
# 1        16.128863     17.442559     26.484357     29.921875     30.070165
# 2        24.993701     19.804688     22.293423     22.531231     18.580875
# 3        30.150310     20.789938     20.754513     18.524912     19.389037
# 4        47.214638     21.719268     24.952943     23.812328     23.302441
# ...            ...           ...           ...           ...           ...
# 1995     18.672179     17.139099     17.375315     16.038869     32.313556
# 1996     16.148312     19.788063     18.487345     23.205303     21.095566
# 1997     20.330706     26.525442     24.775087     18.217448     16.608707
# 1998     16.996632     23.750260     19.550884     19.384368     18.061271
# 1999     19.613084     24.400755     19.584474     23.580674     26.445637
#
#       Amostra_1496  Amostra_1497  Amostra_1498  Amostra_1499
# 0        19.935499     18.030648     19.855672     23.165240
# 1        17.244063     29.927834     17.147152     23.951851
# 2        18.234193     28.692273     19.511498     23.761791
# 3        15.987884     21.550367     13.996479     16.248531
# 4        20.711111     19.248561     17.778822     22.038329
# ...            ...           ...           ...           ...
# 1995     16.902945     19.608322     16.324865     20.152613
# 1996     18.559964     27.514873     24.104497     21.791640
# 1997     18.510888     21.428363     24.050732     17.910004
# 1998     22.377937     21.650525     20.092360     27.679501
# 1999     22.727933     19.210415     26.314472     20.633090
#
# [2000 rows x 1500 columns]

# %% [markdown]
# O Teorema do Limite Central afirma que, **com o aumento do tamanho da amostra, a distribuição das médias amostrais se aproxima de uma distribuição normal** com média igual à média da população e desvio padrão igual ao desvio padrão da variável original dividido pela raiz quadrada do tamanho da amostra. Este fato é assegurado para n maior ou igual a 30.

# %%
amostras.mean().hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# O Teorema do Limite Central afirma que, com o aumento do tamanho da amostra, a distribuição das médias amostrais se aproxima de uma distribuição normal **com média igual à média da população** e desvio padrão igual ao desvio padrão da variável original dividido pela raiz quadrada do tamanho da amostra. Este fato é assegurado para n maior ou igual a 30.

# %%
dados.IMC.mean()
# Out:
# 20.95825220663186

# %%
amostras.mean().mean()
# Out:
# 20.963272047543892

# %% [markdown]
# O Teorema do Limite Central afirma que, com o aumento do tamanho da amostra, a distribuição das médias amostrais se aproxima de uma distribuição normal com média igual à média da população e **desvio padrão igual ao desvio padrão da variável original dividido pela raiz quadrada do tamanho da amostra**. Este fato é assegurado para n maior ou igual a 30.
#
# # $$\sigma_\bar{x} = \frac{\sigma}{\sqrt{n}}$$

# %%
import numpy as np

desvio_padrao_amostra_aproximado = dados.IMC.std()/np.sqrt(n)
print(desvio_padrao_amostra_aproximado)
# Out:
# 0.09490859583922757
